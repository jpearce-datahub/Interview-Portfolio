# %% [markdown]
# ## AWS Covid-19 Data Lake to Athena (using S3 and Crawlers)

# %% [markdown]
# # Resources
#
# https://aws.amazon.com/covid-19-data-lake/
#
# https://dj2taa9i652rf.cloudfront.net/
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Bring data into S3
# ![image.png](attachment:image.png)

# %% [markdown]
# # Create crawlers for each file
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Pull into Athena
# ![image.png](attachment:image.png)
